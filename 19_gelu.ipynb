# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/duoan/TorchCode/blob/master/templates/19_gelu.ipynb)
#
# # 🟢 Easy: GELU Activation
#
# Implement the **GELU** (Gaussian Error Linear Unit) activation.
#
# $$\text{GELU}(x) = x \cdot \Phi(x) = x \cdot 0.5 \cdot (1 + \text{erf}(x / \sqrt{2}))$$
#
# ### Signature
# ```python
# def my_gelu(x: Tensor) -> Tensor: ...
# ```
#
# ### Rules
# - Do NOT use `F.gelu`, `nn.GELU`, or `torch.nn.functional.gelu`
# - Use `torch.erf` for the exact version

# %%
# Install torch-judge in Colab (no-op in JupyterLab/Docker)
try:
    import google.colab
    get_ipython().run_line_magic('pip', 'install -q torch-judge')
except ImportError:
    pass
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.5/48.5 kB 3.5 MB/s eta 0:00:00

# %%
import torch
import math

# %%
# ✏️ YOUR IMPLEMENTATION HERE

def my_gelu(x):
    result = x * 0.5 * (1 + torch.erf(x / math.sqrt(2)))
    return result

# %% [markdown]
# Reason we prefer GELU is because of how it solves the "Dead Neuron" problem from ReLU. ReLU zeroes out negative outputs of neurons, so when the neurons are zeroed out they do not contribute to the training/learning process.
#
# GELU allows for small non-zero negative numbers for non-positive outputs from the neurons, which ensures that the neurons still contribute to learning.

# %%
# 🧪 Debug
x = torch.tensor([-2., -1., 0., 1., 2.])
print('Output:', my_gelu(x))
print('Ref:   ', torch.nn.functional.gelu(x))
# Out:
# Output: tensor([-0.0455, -0.1587,  0.0000,  0.8413,  1.9545])
# Ref:    tensor([-0.0455, -0.1587,  0.0000,  0.8413,  1.9545])

# %%
# ✅ SUBMIT
from torch_judge import check
check('gelu')
# Out:
# 🧪 Testing: GELU Activation (Easy)
# ──────────────────────────────────────────────────
#   ✅ [1/4] Matches F.gelu (33.5ms)
#   ✅ [2/4] gelu(0) = 0 (0.6ms)
#   ✅ [3/4] Shape preservation (0.3ms)
#   ✅ [4/4] Gradient flow (23.7ms)
# ──────────────────────────────────────────────────
#   🎉 All 4 tests passed! (58.1ms total)
#   Progress saved. Run status() to see your dashboard.
